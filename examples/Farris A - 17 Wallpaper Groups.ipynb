# %% [markdown]
# # Appendix A: Cell Diagrams for the 17 Wallpaper Groups

# %%
from symmart.unitcell import SvgwriteCellDiagram
from symmart.wallpaper_groups import wallpaper_generators, wallpaper_lattices
from IPython.display import HTML, display
import numpy as np
from io import StringIO

# %%
scale = 100
cell_params = {
    "monoclinic": (1, .1+1j),
    "rhombic": (.5-.3j, .5+.3j),
    "rectangular": (1, .6j),
    "square": (1,1j),
    "hexagonal": (1, np.exp(2j*np.pi/3)),
}

# %%
html = StringIO("<div>")
for lattice, spacegroups in wallpaper_lattices.items():
    a = scale*cell_params[lattice][0]
    b = scale*cell_params[lattice][1]
    
    html.write(f'<h3>{lattice.capitalize()}</h3>')
    for sg in spacegroups:
        gens = wallpaper_generators[sg]
        dia = SvgwriteCellDiagram(a,b)
        dia.draw_cell()
        dia.draw_ops(gens)
        html.write('<div style="width:120px; display: inline-block;">')
        html.write(dia.tostring())
        html.write(f'<p style="text-align: center;">{sg}</p>')
        html.write('</div>')
        
HTML(html.getvalue())
# Out:
# <h3>Monoclinic</h3><div style="width:120px; display: inline-block;"><svg baseProfile="full" height="100%" version="1.1" viewBox="-10.0,-110.0,130.0,120.0" width="100%" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs /><g transform="matrix(1 0 0 -1 0 0)"><rect fill="white" height="120.0" width="130.0" x="-10.0" y="-10.0" /><line stroke="black" stroke-width="1" x1="0.0" x2="100.0" y1="0.0" y2="0.0" /><line stroke="black" stroke-width="1" x1="100.0" x2="110.0" y1="0.0" y2="100.0" /><line stroke="black" stroke-width="1" x1="110.0" x2="10.0" y1="100.0" y2="100.0" /><line stroke="black" stroke-width="1" x1="10.0" x2="0.0" y1="100.0" y2="0.0" /><circle cx="0" cy="0" fill="red" r="1" /></g></svg><p style="text-align: center;">p1</p></div><div style="width:120px; display: inline-block;"><svg baseProfile="full" height="100%" version="1.1" viewBox="-10.0,-110.0,130.0,120.0" width="100%" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs /><g transform="matrix(1 0 0 -1 0 0)"><rect fill="white" height="120.0" width="130.0" x="-10.0" y="-10.0" /><line stroke="black" stroke-width="1" x1="0.0" x2="100.0" y1="0.0" y2="0.0" /><line stroke="black" stroke-width="1" x1="100.0" x2="110.0" y1="0.0" y2="100.0" /><line stroke="black" stroke-width="1" x1="110.0" x2="10.0" y1="100.0" y2="100.0" /><line stroke="black" stroke-width="1" x1="10.0" x2="0.0" y1="100.0" y2="0.0" /><circle cx="0" cy="0" fill="red" r="1" /><ellipse cx="0.0" cy="0.0" rx="2.5" ry="5" /><ellipse cx="100.0" cy="0.0" rx="2.5" ry="5" /><ellipse cx="10.0" cy="100.0" rx="2.5" ry="5" /><ellipse cx="110.0" cy="100.0" rx="2.5" ry="5" /><ellipse cx="50.0" cy="0.0" rx="2.5" ry="5" /><ellipse cx="60.0" cy="100.0" rx="2.5" ry="5" /><ellipse cx="5.0" cy="50.0" rx="2.5" ry="5" /><ellipse cx="105.0" cy="50.0" rx="2.5" ry="5" /><ellipse cx="55.0" cy="50.0" rx="2.5" ry="5" /></g></svg><p style="text-align: center;">p2</p></div><h3>Rhombic</h3><div style="width:120px; display: inline-block;"><svg baseProfile="full" height="100%" version="1.1" viewBox="-10.0,-40.0,120.0,80.0" width="100%" xmlns="http://www.w3.org/2000/svg" xmlns:ev="http://www.w3.org/2001/xml-events" xmlns:xlink="http://www.w3.org/1999/xlink"><defs /><g transform="matrix(1 0 0 -1 0 0)"><rect fill="white" height="80.0" width="120.0" x="-10.0" y="-40.0" /><line stroke="black" stroke-width="1" x1="0.0" x2="50.0" y1="0.0" y2="-30.0" /><line stroke="black" stroke-width="1" x1="50.0" x2="100.0" y1="-30.0" y2="0.0" /><line stroke="black" stroke-width="1" x1="100.0" x2="50.0" y1="0.0" y2="30.0" /><line stroke="black" stroke-width="1" x1="50.0" x2="0.0" y1="30.0" y2="0.0" /><circle cx="0" cy="0" fill="red" r="1" /><line stroke="white" stroke-width="3" x1="-17.149858514250884" x2="117.14985851425088" y1="0.0" y2="0.0" /><line stroke="grey" stroke-width="1" x1="-17.149858514250884" x2="117.14985851425088" y1="1.0" y2="1.0" /><line stroke="grey" stroke-width="1" x1="-17.149858514250884" x2="117.14985851425088" y1="-1.0" y2="-1.0" /><line stroke="white" stroke-width="3" x1="32.85014148574912" x2="67.14985851425088" y1="30.0" y2="30.0" /><line stroke="grey" stroke-width="1" x1="32.85014148574912" x2="67.14985851425088" y1="31.0" y2="31.0" /><line stroke="grey" stroke-width="1" x1="32.85014148574912" x2="67.14985851425088" y1="29.0" y2="29.0" /><line stroke="white" stroke-width="3" x1="32.85014148574912" x2="67.14985851425088" y1="-30.0" y2="-30.0" /><line stroke="grey" stroke-width="1" x1="32.85014148574912" x2="67.14985851425088" y1="-29.0" y2="-29.0" /><line stroke="grey" stroke-width="1" x1="32.85014148574912" x2="67.14985851425088" y1="-31.0" y2="-31.0" /><line stroke="grey" stroke-dasharray="4,4" stroke-width="1" x1="7.850141485749118" x2="92.14985851425088" y1="-15.0" y2="-15.0" /><line stroke="grey" stroke-dasharray="4,4" stroke-width="1" x1="7.85014148574912" x2="92.14985851425088" y ...
